# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
     if city not in cities:
            cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

    
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narasannapeta
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | brookhaven
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 1 | qinhuangdao
# Processing Record 7 of Set 1 | kolpny
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | wukari
# Processing Record 12 of Set 1 | nishihara
# Processing Record 13 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 14 of Set 1 | ruteng
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | biankouma
# Processing Record 19 of Set 1 | vadso
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | broken hill
# Processing Record 23 of Set 1 | daokou
# Processing Record 24 of Set 1 | mpongwe
# Processing Record 25 of Set 1 | vardo
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | taicheng
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | rocha
# Processing Record 33 of Set 1 | celestun
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | pochutla
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | sinnamary
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | cairns
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | mackay
# Processing Record 44 of Set 1 | honiara
# Processing Record 45 of Set 1 | oranjemund
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | kavaratti
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | spassk
# Processing Record 4 of Set 2 | marsaxlokk
# Processing Record 5 of Set 2 | havelock
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | sungaipenuh
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | tabuk
# Processing Record 12 of Set 2 | ayan
# Processing Record 13 of Set 2 | kamsack
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | rostaq
# City not found. Skipping...
# Processing Record 17 of Set 2 | dundee
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | berlevag
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | korla
# Processing Record 32 of Set 2 | pacific grove
# Processing Record 33 of Set 2 | baruun-urt
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | ossora
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | ust-omchug
# Processing Record 43 of Set 2 | telciu
# Processing Record 44 of Set 2 | rakhya
# City not found. Skipping...
# Processing Record 45 of Set 2 | kirakira
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | sangar
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | natal
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | superior
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | vostok
# Processing Record 5 of Set 3 | anaco
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 3 | belmonte
# Processing Record 9 of Set 3 | maneadero
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | port pirie
# Processing Record 12 of Set 3 | ngawen
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | itarema
# Processing Record 15 of Set 3 | parista
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | pasni
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | bilma
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | kimbe
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | pauini
# Processing Record 24 of Set 3 | aguimes
# Processing Record 25 of Set 3 | mount gambier
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto del rosario
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | impfondo
# Processing Record 30 of Set 3 | lulea
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | grandola
# Processing Record 35 of Set 3 | saint-denis
# Processing Record 36 of Set 3 | saint-joseph
# Processing Record 37 of Set 3 | tuy hoa
# Processing Record 38 of Set 3 | nautla
# Processing Record 39 of Set 3 | axim
# Processing Record 40 of Set 3 | flin flon
# Processing Record 41 of Set 3 | bereznik
# Processing Record 42 of Set 3 | fernie
# Processing Record 43 of Set 3 | kenitra
# Processing Record 44 of Set 3 | gwanda
# Processing Record 45 of Set 3 | salalah
# Processing Record 46 of Set 3 | netanya
# Processing Record 47 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 3 | selkirk
# Processing Record 49 of Set 3 | khislavichi
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | ulladulla
# Processing Record 2 of Set 4 | papar
# Processing Record 3 of Set 4 | ribeira brava
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | thinadhoo
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | tara
# Processing Record 8 of Set 4 | dubbo
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | poltavka
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | ichinohe
# Processing Record 13 of Set 4 | khani
# Processing Record 14 of Set 4 | pietersburg
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | piat
# Processing Record 18 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 4 | mayo
# Processing Record 20 of Set 4 | shetpe
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint-nazaire
# Processing Record 24 of Set 4 | dicabisagan
# Processing Record 25 of Set 4 | ternate
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | amazar
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | cabedelo
# Processing Record 30 of Set 4 | frederick
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | tateyama
# Processing Record 34 of Set 4 | wenatchee
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | yondo
# Processing Record 38 of Set 4 | roma
# Processing Record 39 of Set 4 | kuito
# Processing Record 40 of Set 4 | hambantota
# Processing Record 41 of Set 4 | paramonga
# Processing Record 42 of Set 4 | liling
# Processing Record 43 of Set 4 | mutsu
# Processing Record 44 of Set 4 | uromi
# Processing Record 45 of Set 4 | sao sebastiao
# Processing Record 46 of Set 4 | naugachhia
# Processing Record 47 of Set 4 | talakan
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | ancud
# Processing Record 1 of Set 5 | rognan
# Processing Record 2 of Set 5 | maraa
# Processing Record 3 of Set 5 | virginia beach
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | jalna
# Processing Record 6 of Set 5 | qaqortoq
# Processing Record 7 of Set 5 | kroya
# Processing Record 8 of Set 5 | neman
# Processing Record 9 of Set 5 | ucluelet
# Processing Record 10 of Set 5 | agadir
# Processing Record 11 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 5 | suoyarvi
# Processing Record 13 of Set 5 | oussouye
# Processing Record 14 of Set 5 | codrington
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | bac lieu
# Processing Record 17 of Set 5 | mastic beach
# Processing Record 18 of Set 5 | tselinnoye
# Processing Record 19 of Set 5 | yuncheng
# Processing Record 20 of Set 5 | gao
# Processing Record 21 of Set 5 | eyl
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | pineville
# Processing Record 24 of Set 5 | mutis
# Processing Record 25 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 5 | peterhead
# Processing Record 29 of Set 5 | najran
# Processing Record 30 of Set 5 | sydney
# Processing Record 31 of Set 5 | avera
# Processing Record 32 of Set 5 | waddan
# Processing Record 33 of Set 5 | banda aceh
# Processing Record 34 of Set 5 | iquitos
# Processing Record 35 of Set 5 | benghazi
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | treinta y tres
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | bashtanka
# Processing Record 40 of Set 5 | manitouwadge
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | shigony
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | shawville
# Processing Record 45 of Set 5 | kibre mengist
# Processing Record 46 of Set 5 | coquimbo
# Processing Record 47 of Set 5 | dauphin
# Processing Record 48 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | tooele
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 6 | san carlos
# Processing Record 5 of Set 6 | mashivka
# Processing Record 6 of Set 6 | sao jose da coroa grande
# Processing Record 7 of Set 6 | masvingo
# Processing Record 8 of Set 6 | novo horizonte
# Processing Record 9 of Set 6 | cape town
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | ouargaye
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | estelle
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | ponta do sol
# Processing Record 16 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 6 | peniche
# Processing Record 18 of Set 6 | ayagoz
# Processing Record 19 of Set 6 | wapakoneta
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | port elizabeth
# Processing Record 22 of Set 6 | kilis
# Processing Record 23 of Set 6 | high rock
# Processing Record 24 of Set 6 | kholm
# Processing Record 25 of Set 6 | sola
# Processing Record 26 of Set 6 | santa helena de goias
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | kovur
# Processing Record 29 of Set 6 | shuangyang
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | necochea
# Processing Record 32 of Set 6 | clarence town
# Processing Record 33 of Set 6 | port augusta
# Processing Record 34 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 6 | worland
# Processing Record 36 of Set 6 | vao
# Processing Record 37 of Set 6 | sioux lookout
# Processing Record 38 of Set 6 | quatre cocos
# Processing Record 39 of Set 6 | diapaga
# Processing Record 40 of Set 6 | ratekau
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | gat
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | spencer
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | vaini
# Processing Record 48 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 6 | bandarbeyla
# Processing Record 50 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | wajima
# Processing Record 4 of Set 7 | pisco
# Processing Record 5 of Set 7 | guigue
# Processing Record 6 of Set 7 | pinawa
# Processing Record 7 of Set 7 | halifax
# Processing Record 8 of Set 7 | porto belo
# Processing Record 9 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 7 | otradnoye
# Processing Record 11 of Set 7 | yeppoon
# Processing Record 12 of Set 7 | dharchula
# Processing Record 13 of Set 7 | mahanje
# Processing Record 14 of Set 7 | griffith
# Processing Record 15 of Set 7 | safaga
# Processing Record 16 of Set 7 | yar-sale
# Processing Record 17 of Set 7 | buala
# Processing Record 18 of Set 7 | melfi
# Processing Record 19 of Set 7 | belaya kholunitsa
# Processing Record 20 of Set 7 | morant bay
# Processing Record 21 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 7 | aginskoye
# Processing Record 23 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | burnie
# Processing Record 26 of Set 7 | mangrol
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | chara
# Processing Record 29 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 7 | mbekenyera
# Processing Record 31 of Set 7 | tura
# Processing Record 32 of Set 7 | gurjaani
# Processing Record 33 of Set 7 | leicester
# Processing Record 34 of Set 7 | lichinga
# Processing Record 35 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 36 of Set 7 | villefranche-sur-saone
# Processing Record 37 of Set 7 | dingle
# Processing Record 38 of Set 7 | karpogory
# Processing Record 39 of Set 7 | upata
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | walvis bay
# Processing Record 42 of Set 7 | bengkulu
# Processing Record 43 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 7 | kavieng
# Processing Record 46 of Set 7 | atambua
# Processing Record 47 of Set 7 | gashua
# Processing Record 48 of Set 7 | mount isa
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | comodoro rivadavia
# Processing Record 1 of Set 8 | wuan
# Processing Record 2 of Set 8 | blagoyevo
# Processing Record 3 of Set 8 | galle
# Processing Record 4 of Set 8 | dakar
# Processing Record 5 of Set 8 | dhidhdhoo
# Processing Record 6 of Set 8 | muhos
# Processing Record 7 of Set 8 | sept-iles
# Processing Record 8 of Set 8 | majene
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | hervey bay
# Processing Record 11 of Set 8 | ambon
# Processing Record 12 of Set 8 | tsalka
# Processing Record 13 of Set 8 | santa cruz
# Processing Record 14 of Set 8 | northam
# Processing Record 15 of Set 8 | goma
# Processing Record 16 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 8 | rudnya
# Processing Record 18 of Set 8 | kodinsk
# Processing Record 19 of Set 8 | buchanan
# Processing Record 20 of Set 8 | puerto colombia
# Processing Record 21 of Set 8 | te anau
# Processing Record 22 of Set 8 | palana
# Processing Record 23 of Set 8 | chirilagua
# Processing Record 24 of Set 8 | swellendam
# Processing Record 25 of Set 8 | samarai
# Processing Record 26 of Set 8 | hirara
# Processing Record 27 of Set 8 | new smyrna beach
# Processing Record 28 of Set 8 | tuatapere
# Processing Record 29 of Set 8 | pandan
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | poso
# Processing Record 32 of Set 8 | hofn
# Processing Record 33 of Set 8 | faya
# Processing Record 34 of Set 8 | los alamos
# Processing Record 35 of Set 8 | viedma
# Processing Record 36 of Set 8 | payo
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | kargil
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 8 | baghdad
# Processing Record 43 of Set 8 | bousso
# Processing Record 44 of Set 8 | veshenskaya
# Processing Record 45 of Set 8 | nova olimpia
# Processing Record 46 of Set 8 | lima
# Processing Record 47 of Set 8 | nurota
# Processing Record 48 of Set 8 | nuevitas
# Processing Record 49 of Set 8 | georgetown
# Processing Record 50 of Set 8 | luz
# Processing Record 1 of Set 9 | marienburg
# Processing Record 2 of Set 9 | rock springs
# Processing Record 3 of Set 9 | gold coast
# Processing Record 4 of Set 9 | jalu
# Processing Record 5 of Set 9 | giaginskaya
# Processing Record 6 of Set 9 | salinas
# Processing Record 7 of Set 9 | montrose
# Processing Record 8 of Set 9 | bogande
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | lamu
# Processing Record 11 of Set 9 | marzuq
# Processing Record 12 of Set 9 | whitehorse
# Processing Record 13 of Set 9 | pak phanang
# Processing Record 14 of Set 9 | san cristobal
# Processing Record 15 of Set 9 | miri
# Processing Record 16 of Set 9 | mykhaylivka
# Processing Record 17 of Set 9 | maragogi
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | port blair
# Processing Record 20 of Set 9 | ambulu
# Processing Record 21 of Set 9 | makasar
# Processing Record 22 of Set 9 | umm kaddadah
# Processing Record 23 of Set 9 | juba
# Processing Record 24 of Set 9 | mishan
# Processing Record 25 of Set 9 | kemi
# Processing Record 26 of Set 9 | lithakia
# Processing Record 27 of Set 9 | harnai
# Processing Record 28 of Set 9 | kieta
# Processing Record 29 of Set 9 | kempsey
# Processing Record 30 of Set 9 | oistins
# Processing Record 31 of Set 9 | mahajanga
# Processing Record 32 of Set 9 | meulaboh
# Processing Record 33 of Set 9 | pangkalanbuun
# Processing Record 34 of Set 9 | epitalion
# Processing Record 35 of Set 9 | jojoima
# Processing Record 36 of Set 9 | cherepovets
# Processing Record 37 of Set 9 | valparaiso
# Processing Record 38 of Set 9 | taree
# Processing Record 39 of Set 9 | havoysund
# Processing Record 40 of Set 9 | ocosingo
# Processing Record 41 of Set 9 | fort-shevchenko
# Processing Record 42 of Set 9 | mormugao
# Processing Record 43 of Set 9 | sile
# Processing Record 44 of Set 9 | brewster
# Processing Record 45 of Set 9 | khasan
# Processing Record 46 of Set 9 | acapulco
# Processing Record 47 of Set 9 | poniatowa
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | port-cartier
# Processing Record 50 of Set 9 | ustka
# Processing Record 1 of Set 10 | naziya
# Processing Record 2 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 10 | morros
# Processing Record 4 of Set 10 | la ronge
# Processing Record 5 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 10 | oktyabrskiy
# Processing Record 7 of Set 10 | lac du bonnet
# Processing Record 8 of Set 10 | bosaso
# Processing Record 9 of Set 10 | adrar
# Processing Record 10 of Set 10 | presidencia roque saenz pena
# Processing Record 11 of Set 10 | mezen
# Processing Record 12 of Set 10 | shingu
# Processing Record 13 of Set 10 | saint george
# Processing Record 14 of Set 10 | kuandian
# Processing Record 15 of Set 10 | svetlyy
# Processing Record 16 of Set 10 | arrecife
# Processing Record 17 of Set 10 | grand gaube
# Processing Record 18 of Set 10 | mersing
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | nabire
# Processing Record 22 of Set 10 | barras
# Processing Record 23 of Set 10 | oeiras
# Processing Record 24 of Set 10 | tazovskiy
# Processing Record 25 of Set 10 | kiunga
# Processing Record 26 of Set 10 | lalsk
# Processing Record 27 of Set 10 | winnemucca
# Processing Record 28 of Set 10 | tahoua
# Processing Record 29 of Set 10 | pelym
# Processing Record 30 of Set 10 | makakilo city
# Processing Record 31 of Set 10 | surgut
# Processing Record 32 of Set 10 | sorong
# Processing Record 33 of Set 10 | natchez
# Processing Record 34 of Set 10 | bogale
# Processing Record 35 of Set 10 | moranbah
# Processing Record 36 of Set 10 | ampanihy
# Processing Record 37 of Set 10 | graaff-reinet
# Processing Record 38 of Set 10 | bacolod
# Processing Record 39 of Set 10 | ashukino
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | pemba
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | margate
# Processing Record 44 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 45 of Set 10 | merauke
# Processing Record 46 of Set 10 | uthal
# Processing Record 47 of Set 10 | san
# Processing Record 48 of Set 10 | lovozero
# Processing Record 49 of Set 10 | shima
# Processing Record 50 of Set 10 | mahibadhoo
# Processing Record 1 of Set 11 | aldama
# Processing Record 2 of Set 11 | labuhan
# Processing Record 3 of Set 11 | puerto madero
# Processing Record 4 of Set 11 | suntar
# Processing Record 5 of Set 11 | burns lake
# Processing Record 6 of Set 11 | madimba
# Processing Record 7 of Set 11 | ormara
# Processing Record 8 of Set 11 | prince rupert
# Processing Record 9 of Set 11 | paamiut
# Processing Record 10 of Set 11 | saint marys
# Processing Record 11 of Set 11 | ranong
# Processing Record 12 of Set 11 | salaga
# Processing Record 13 of Set 11 | vestmannaeyjar
# Processing Record 14 of Set 11 | qiqihar
# Processing Record 15 of Set 11 | odweyne
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | umm lajj
# Processing Record 18 of Set 11 | souillac
# Processing Record 19 of Set 11 | miami
# Processing Record 20 of Set 11 | riyadh
# Processing Record 21 of Set 11 | chapais
# Processing Record 22 of Set 11 | lomovka
# Processing Record 23 of Set 11 | nagato
# Processing Record 24 of Set 11 | urusha
# Processing Record 25 of Set 11 | holme
# Processing Record 26 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 11 | srednekolymsk
# Processing Record 28 of Set 11 | sumbe
# Processing Record 29 of Set 11 | baijiantan
# Processing Record 30 of Set 11 | saint-pierre
# Processing Record 31 of Set 11 | bongandanga
# Processing Record 32 of Set 11 | troitskoye
# Processing Record 33 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 11 | sumen
# City not found. Skipping...
# Processing Record 35 of Set 11 | villa vazquez
# City not found. Skipping...
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | longyearbyen
# Processing Record 38 of Set 11 | atar
# Processing Record 39 of Set 11 | tecoanapa
# Processing Record 40 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 11 | sandy springs
# Processing Record 42 of Set 11 | jever
# Processing Record 43 of Set 11 | bereda
# Processing Record 44 of Set 11 | mbamba
# Processing Record 45 of Set 11 | lieksa
# Processing Record 46 of Set 11 | okhotsk
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 11 | krasnoyarka
# Processing Record 50 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 12 | thurso
# Processing Record 2 of Set 12 | nueve de julio
# Processing Record 3 of Set 12 | areosa
# Processing Record 4 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 5 of Set 12 | tanete
# Processing Record 6 of Set 12 | torbat-e jam
# Processing Record 7 of Set 12 | cayenne
# Processing Record 8 of Set 12 | harbour breton
# Processing Record 9 of Set 12 | alta
# Processing Record 10 of Set 12 | cedar city
# Processing Record 11 of Set 12 | belmopan
# Processing Record 12 of Set 12 | san juan
# Processing Record 13 of Set 12 | haines junction
# Processing Record 14 of Set 12 | tautira
# Processing Record 15 of Set 12 | batemans bay
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | laguna
# Processing Record 18 of Set 12 | anito
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 12 | san carlos de bariloche
# Processing Record 23 of Set 12 | portales
# Processing Record 24 of Set 12 | fuji
# Processing Record 25 of Set 12 | jasper
# Processing Record 26 of Set 12 | kisangani
# Processing Record 27 of Set 12 | henties bay
# Processing Record 28 of Set 12 | iquique
# Processing Record 29 of Set 12 | soria
# Processing Record 30 of Set 12 | batagay-alyta
# Processing Record 31 of Set 12 | pithoro
# Processing Record 32 of Set 12 | kalangala
# Processing Record 33 of Set 12 | methoni
# Processing Record 34 of Set 12 | kichera
# Processing Record 35 of Set 12 | havre-saint-pierre
# Processing Record 36 of Set 12 | guiratinga
# Processing Record 37 of Set 12 | saquena
# Processing Record 38 of Set 12 | bayshore gardens
# Processing Record 39 of Set 12 | grindavik
# Processing Record 40 of Set 12 | marawi
# Processing Record 41 of Set 12 | islamkot
# Processing Record 42 of Set 12 | ghatampur
# Processing Record 43 of Set 12 | wagar
# Processing Record 44 of Set 12 | abha
# Processing Record 45 of Set 12 | antofagasta
# Processing Record 46 of Set 12 | wanning
# Processing Record 47 of Set 12 | aklavik
# Processing Record 48 of Set 12 | padang
# Processing Record 49 of Set 12 | valley city
# Processing Record 50 of Set 12 | dudinka
# Processing Record 1 of Set 13 | half moon bay
# Processing Record 2 of Set 13 | aksu
# Processing Record 3 of Set 13 | taltal
# Processing Record 4 of Set 13 | rosetta
# Processing Record 5 of Set 13 | dagana
# Processing Record 6 of Set 13 | tual
# Processing Record 7 of Set 13 | shemonaikha
# Processing Record 8 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 13 | high level
# Processing Record 10 of Set 13 | waipawa
# Processing Record 11 of Set 13 | saquarema
# Processing Record 12 of Set 13 | biak
# Processing Record 13 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 13 | tommot
# Processing Record 15 of Set 13 | moindou
# Processing Record 16 of Set 13 | dariba
# Processing Record 17 of Set 13 | nyimba
# Processing Record 18 of Set 13 | santa fe
# Processing Record 19 of Set 13 | suba
# Processing Record 20 of Set 13 | vaitape
# Processing Record 21 of Set 13 | luderitz
# Processing Record 22 of Set 13 | danville
# Processing Record 23 of Set 13 | isabela
# Processing Record 24 of Set 13 | falkoping
# City not found. Skipping...
# Processing Record 25 of Set 13 | ishnya
# Processing Record 26 of Set 13 | vila franca do campo
# Processing Record 27 of Set 13 | gilbues
# Processing Record 28 of Set 13 | ovalle
# Processing Record 29 of Set 13 | tilichiki
# Processing Record 30 of Set 13 | behshahr
# Processing Record 31 of Set 13 | alekseyevka
# Processing Record 32 of Set 13 | nhulunbuy
# Processing Record 33 of Set 13 | iberia
# Processing Record 34 of Set 13 | araouane
# Processing Record 35 of Set 13 | sarangani
# Processing Record 36 of Set 13 | birecik
# Processing Record 37 of Set 13 | maldonado
# Processing Record 38 of Set 13 | yotoco
# Processing Record 39 of Set 13 | fayetteville
# Processing Record 40 of Set 13 | santa maria
# Processing Record 41 of Set 13 | morro bay
# Processing Record 42 of Set 13 | gisborne
# Processing Record 43 of Set 13 | khandagayty
# Processing Record 44 of Set 13 | mandalgovi
# Processing Record 45 of Set 13 | esso
# Processing Record 46 of Set 13 | raudeberg
# Processing Record 47 of Set 13 | thunder bay
# Processing Record 48 of Set 13 | ndele
# Processing Record 49 of Set 13 | mandaguacu
# Processing Record 50 of Set 13 | qasigiannguit
# Processing Record 1 of Set 14 | lucatan
# City not found. Skipping...
# Processing Record 2 of Set 14 | uk
# City not found. Skipping...
# Processing Record 3 of Set 14 | weyburn
# Processing Record 4 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 14 | emmett
# Processing Record 8 of Set 14 | north bend
# Processing Record 9 of Set 14 | murakami
# Processing Record 10 of Set 14 | urbano santos
# Processing Record 11 of Set 14 | taquari
# Processing Record 12 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 14 | sabanagrande
# Processing Record 14 of Set 14 | yeniseysk
# Processing Record 15 of Set 14 | vanimo
# Processing Record 16 of Set 14 | opuwo
# Processing Record 17 of Set 14 | mixtepec
# City not found. Skipping...
# Processing Record 18 of Set 14 | smirnykh
# Processing Record 19 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 14 | piranhas
# Processing Record 21 of Set 14 | nam som
# Processing Record 22 of Set 14 | hurricane
# Processing Record 23 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 24 of Set 14 | talara
# Processing Record 25 of Set 14 | huilong
# Processing Record 26 of Set 14 | chekhov
# Processing Record 27 of Set 14 | flinders
# Processing Record 28 of Set 14 | skibbereen
# Processing Record 29 of Set 14 | eyrarbakki
# Processing Record 30 of Set 14 | elverum
# Processing Record 31 of Set 14 | naryan-mar
# Processing Record 32 of Set 14 | durusu
# Processing Record 33 of Set 14 | bolshoy lug
# Processing Record 34 of Set 14 | gaya
# Processing Record 35 of Set 14 | kolhapur
# Processing Record 36 of Set 14 | kandrian
# Processing Record 37 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 14 | port hawkesbury
# Processing Record 39 of Set 14 | jiangyou
# Processing Record 40 of Set 14 | manaure
# Processing Record 41 of Set 14 | codajas
# Processing Record 42 of Set 14 | mahon
# Processing Record 43 of Set 14 | mahanoro
# Processing Record 44 of Set 14 | deputatskiy
# Processing Record 45 of Set 14 | juneau
# Processing Record 46 of Set 14 | gainesville
# Processing Record 47 of Set 14 | twin falls
# Processing Record 48 of Set 14 | orsk
# Processing Record 49 of Set 14 | vung tau
# Processing Record 50 of Set 14 | sabang
# Processing Record 1 of Set 15 | inuvik
# Processing Record 2 of Set 15 | progreso
# Processing Record 3 of Set 15 | the valley
# Processing Record 4 of Set 15 | maamba
# Processing Record 5 of Set 15 | middelburg
# Processing Record 6 of Set 15 | bom jesus da lapa
# Processing Record 7 of Set 15 | zhob
# Processing Record 8 of Set 15 | cleethorpes
# Processing Record 9 of Set 15 | warmbad
# Processing Record 10 of Set 15 | nakhodka
# Processing Record 11 of Set 15 | saint-augustin
# Processing Record 12 of Set 15 | porto novo
# Processing Record 13 of Set 15 | tadepallegudem
# Processing Record 14 of Set 15 | ecclefechan
# Processing Record 15 of Set 15 | kaeo
# Processing Record 16 of Set 15 | arman
# Processing Record 17 of Set 15 | pashiya
# Processing Record 18 of Set 15 | capellania
# Processing Record 19 of Set 15 | novaya ladoga
# Processing Record 20 of Set 15 | turochak
# Processing Record 21 of Set 15 | watertown
# Processing Record 22 of Set 15 | billings
# Processing Record 23 of Set 15 | conil
# Processing Record 24 of Set 15 | amuntai
# Processing Record 25 of Set 15 | toktogul
# Processing Record 26 of Set 15 | kanye
# Processing Record 27 of Set 15 | innisfail
# Processing Record 28 of Set 15 | kande
# Processing Record 29 of Set 15 | husavik
# Processing Record 30 of Set 15 | epe
# Processing Record 31 of Set 15 | kushima
# Processing Record 32 of Set 15 | taga dzong
# City not found. Skipping...
# Processing Record 33 of Set 15 | bonthe
# Processing Record 34 of Set 15 | pastavy
# Processing Record 35 of Set 15 | mineiros
# Processing Record 36 of Set 15 | pushkino
# Processing Record 37 of Set 15 | pestravka
# Processing Record 38 of Set 15 | ambatofinandrahana
# Processing Record 39 of Set 15 | sars
# Processing Record 40 of Set 15 | dunedin
# Processing Record 41 of Set 15 | swadlincote
# Processing Record 42 of Set 15 | kudahuvadhoo
# Processing Record 43 of Set 15 | moissala
# Processing Record 44 of Set 15 | santa cecilia
# Processing Record 45 of Set 15 | soloneshnoye
# Processing Record 46 of Set 15 | sterling
# Processing Record 47 of Set 15 | smidovich
# Processing Record 48 of Set 15 | prokhorovka
# Processing Record 49 of Set 15 | largo
# Processing Record 50 of Set 15 | iskateley
# Processing Record 1 of Set 16 | bowral
# Processing Record 2 of Set 16 | kenai
# Processing Record 3 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 16 | jujuy
# City not found. Skipping...
# Processing Record 6 of Set 16 | parati
# Processing Record 7 of Set 16 | ambilobe
# Processing Record 8 of Set 16 | beloha
# Processing Record 9 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 16 | linchuan
# City not found. Skipping...
# Processing Record 11 of Set 16 | catumbela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Narasannapeta  18.4167   84.0500     79.97        86         100
# 1            Auki  -8.7676  160.7034     76.98        88           6
# 2      Brookhaven  31.5791  -90.4407     64.80        49           0
# 3        Hermanus -34.4187   19.2345     63.81        71         100
# 4     Qinhuangdao  39.9317  119.5883     68.20        83           0
# 5          Kolpny  52.2282   37.0368     60.84        89          52
# 6         Kahului  20.8947 -156.4700     79.84        74         100
# 7  Ribeira Grande  38.5167  -28.7000     73.80        56          75
# 8          Kodiak  57.7900 -152.4072     35.11        93          40
# 9          Wukari   7.8500    9.7833     84.65        66          98
#
#    Wind Speed Country Current Description
# 0        8.14      IN     overcast clouds
# 1        3.31      SB           clear sky
# 2        7.67      US           clear sky
# 3       15.03      ZA     overcast clouds
# 4        5.86      CN           clear sky
# 5        5.61      RU       broken clouds
# 6        5.99      US     overcast clouds
# 7        4.61      PT       broken clouds
# 8        6.91      US                mist
# 9        2.75      NG     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df_org = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_df_org]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Narasannapeta      IN  18.4167   84.0500     79.97        86         100
# 1             Auki      SB  -8.7676  160.7034     76.98        88           6
# 2       Brookhaven      US  31.5791  -90.4407     64.80        49           0
# 3         Hermanus      ZA -34.4187   19.2345     63.81        71         100
# 4      Qinhuangdao      CN  39.9317  119.5883     68.20        83           0
# ..             ...     ...      ...       ...       ...       ...         ...
# 689          Kenai      US  60.5544 -151.2583     47.08        98         100
# 690         Parati      BR -23.2178  -44.7131     66.97        94         100
# 691       Ambilobe      MG -13.2000   49.0500     75.65        59          15
# 692         Beloha      MG -25.1667   45.0500     78.53        37           0
# 693      Catumbela      AO -12.4314   13.5472     75.70        79          62
#
#      Wind Speed Current Description
# 0          8.14     overcast clouds
# 1          3.31           clear sky
# 2          7.67           clear sky
# 3         15.03     overcast clouds
# 4          5.86           clear sky
# ..          ...                 ...
# 689        3.44          light rain
# 690        4.27     overcast clouds
# 691        4.36          few clouds
# 692        7.90           clear sky
# 693        8.88          light rain
#
# [694 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 694 non-null    object
#  1   Country              694 non-null    object
#  2   Lat                  694 non-null    float64
#  3   Lng                  694 non-null    float64
#  4   Max Temp             694 non-null    float64
#  5   Humidity             694 non-null    int64
#  6   Cloudiness           694 non-null    int64
#  7   Wind Speed           694 non-null    float64
#  8   Current Description  694 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 48.9+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
